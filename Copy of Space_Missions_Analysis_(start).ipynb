# %% [markdown]
# # Introduction

# %% [markdown]
# <center><img src="https://i.imgur.com/9hLRsjZ.jpg" height=400></center>
#
# This dataset was scraped from [nextspaceflight.com](https://nextspaceflight.com/launches/past/?page=1) and includes all the space missions since the beginning of Space Race between the USA and the Soviet Union in 1957!

# %% [markdown]
# ### Install Package with Country Codes

# %%
# %pip install iso3166
# Out:
# Requirement already satisfied: iso3166 in /usr/local/lib/python3.10/dist-packages (2.1.1)

# %% [markdown]
# ### Upgrade Plotly
#
# Run the cell below if you are working with Google Colab.

# %%
# %pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)

# %% [markdown]
# ### Import Statements

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# These might be helpful:
from iso3166 import countries
from datetime import datetime, timedelta

# %% [markdown]
# ### Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Load the Data

# %%
df_data = pd.read_csv('mission_launches.csv')

# %% [markdown]
# # Preliminary Data Exploration
#
# * What is the shape of `df_data`?
# * How many rows and columns does it have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
print(f"the shape of the data frame is: {df_data.shape}")
print(f"Name of each column: { df_data.columns }")
print(f"Number of columns: { len(df_data.columns) }")
print(f"Number of row: { len(df_data) }")
print(f"NAN values:")
print(df_data.isna())
print(f"duplicate values:")
print(df_data.duplicated())
# Out:
# the shape of the data frame is: (4324, 9)
# Name of each column: Index(['Unnamed: 0.1', 'Unnamed: 0', 'Organisation', 'Location', 'Date',
#        'Detail', 'Rocket_Status', 'Price', 'Mission_Status'],
#       dtype='object')
# Number of columns: 9
# Number of row: 4324
# NAN values:
#       Unnamed: 0.1  Unnamed: 0  Organisation  Location   Date  Detail  \
# 0            False       False         False     False  False   False
# 1            False       False         False     False  False   False
# 2            False       False         False     False  False   False
# 3            False       False         False     False  False   False
# 4            False       False         False     False  False   False
# ...            ...         ...           ...       ...    ...     ...
# 4319         False       False         False     False  False   False
# 4320         False       False         False     False  False   False
# 4321         False       False         False     False  False   False
# 4322         False       False         False     False  False   False
# 4323         False       False         False     False  False   False
#
#       Rocket_Status  Price  Mission_Status
# 0             False  False           False
# 1             False  False           False
# 2             False   True           False
# 3             False  False           False
# 4             False  False           False
# ...             ...    ...             ...
# 4319          False   True           False
# 4320          False   True           False
# 4321          False   True           False
# 4322          False   True           False
# 4323          False   True           False
#
# [4324 rows x 9 columns]
# duplicate values:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4319    False
# 4320    False
# 4321    False
# 4322    False
# 4323    False
# Length: 4324, dtype: bool

# %%
type(df_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates
#
# Consider removing columns containing junk data.

# %%
df_data = df_data.drop_duplicates()

# %%
df_data = df_data.dropna()

# %% [markdown]
# ## Descriptive Statistics

# %%
df_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 3             3           3    Roscosmos
# 4             4           4          ULA
# 5             5           5         CASC
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
# 5       LC-9, Taiyuan Satellite Launch Center, China
#
#                          Date  \
# 0  Fri Aug 07, 2020 05:12 UTC
# 1  Thu Aug 06, 2020 04:01 UTC
# 3  Thu Jul 30, 2020 21:25 UTC
# 4  Thu Jul 30, 2020 11:50 UTC
# 5  Sat Jul 25, 2020 03:13 UTC
#
#                                               Detail Rocket_Status  Price  \
# 0       Falcon 9 Block 5 | Starlink V1 L9 & BlackSky  StatusActive   50.0
# 1                Long March 2D | Gaofen-9 04 & Q-SAT  StatusActive  29.75
# 3       Proton-M/Briz-M | Ekspress-80 & Ekspress-103  StatusActive   65.0
# 4                         Atlas V 541 | Perseverance  StatusActive  145.0
# 5  Long March 4B | Ziyuan-3 03, Apocalypse-10 & N...  StatusActive  64.68
#
#   Mission_Status
# 0        Success
# 1        Success
# 3        Success
# 4        Success
# 5        Success

# %% [markdown]
# # Number of Launches per Company
#
# Create a chart that shows the number of space mission launches by organisation.

# %%
df_data_set_counts = df_data['Organisation'].value_counts()

# %%
# x='Organisation', y='Number of launches'
# plt.ylabel('Org')
# plt.xlabel('Count')
# plt.title('Number of Launches per company')
px.bar(df_data_set_counts)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="c3b32425-5297-4b84-bc14-db2b5a238223" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3b32425-5297-4b84-bc14-db2b5a238223")) {                    Plotly.newPlot(                        "c3b32425-5297-4b84-bc14-db2b5a238223",                        [{"alignmentgroup":"True","hovertemplate":"variable=Organisation\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Organisation","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Organisation","offsetgroup":"Organisation","orientation":"v","showlegend":true,"textposition":"auto","x":["CASC","NASA","SpaceX","ULA","Arianespace","Northrop","ISRO","MHI","VKS RF","US Air Force","Roscosmos","Kosmotras","ILS","Eurockot","Rocket Lab","Martin Marietta","Lockheed","Boeing","JAXA","RVSN USSR","Sandia","Virgin Orbit","ESA","ExPace","EER"],"xaxis":"x","y":[158,149,99,98,96,83,67,37,33,26,23,22,13,13,13,9,8,7,3,2,1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpol ...

# %% [markdown]
# # Number of Active versus Retired Rockets
#
# How many rockets are active compared to those that are decomissioned?

# %%
df_data_set_counts = df_data['Rocket_Status'].value_counts()

# %%
px.bar(df_data_set_counts)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="fc6218fc-e2f0-444f-b940-790ddd77d8ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc6218fc-e2f0-444f-b940-790ddd77d8ba")) {                    Plotly.newPlot(                        "fc6218fc-e2f0-444f-b940-790ddd77d8ba",                        [{"alignmentgroup":"True","hovertemplate":"variable=Rocket_Status\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rocket_Status","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Rocket_Status","offsetgroup":"Rocket_Status","orientation":"v","showlegend":true,"textposition":"auto","x":["StatusActive","StatusRetired"],"xaxis":"x","y":[586,378],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type ...

# %% [markdown]
# # Distribution of Mission Status
#
# How many missions were successful?
# How many missions failed?

# %%
df_data_set_counts = df_data['Mission_Status'].value_counts()

# %%
px.bar(df_data_set_counts)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="9e40d743-0242-458a-b4da-46eaa0851dc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e40d743-0242-458a-b4da-46eaa0851dc0")) {                    Plotly.newPlot(                        "9e40d743-0242-458a-b4da-46eaa0851dc0",                        [{"alignmentgroup":"True","hovertemplate":"variable=Mission_Status\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mission_Status","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mission_Status","offsetgroup":"Mission_Status","orientation":"v","showlegend":true,"textposition":"auto","x":["Success","Failure","Partial Failure","Prelaunch Failure"],"xaxis":"x","y":[910,36,17,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}, ...

# %% [markdown]
# # How Expensive are the Launches?
#
# Create a histogram and visualise the distribution. The price column is given in USD millions (careful of missing values).

# %%
for row in df_data.index:
  price = df_data.loc[row, ['Price']]
  try:
    intprice = float(price)
  except ValueError:
    intprice = float(price.str.replace(",",""))
  df_data.loc[row, ['Price']] = intprice
df_data_set_counts = df_data['Price'].value_counts()

# %%
plt.figure(
    figsize=(
        8,
        4
    ),
    dpi=200
)
sns.histplot(
    data=df_data,
    x=df_data.Price,
    bins=5

)
plt.xlabel('Price (Millions)')
plt.xticks(rotation = 45, fontsize=5)
plt.title('Launch Prices')
plt.show()

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Launches by Country
#
# * Create a choropleth map using [the plotly documentation](https://plotly.com/python/choropleth-maps/)
# * Experiment with [plotly's available colours](https://plotly.com/python/builtin-colorscales/). I quite like the sequential colour `matter` on this map.
# * You'll need to extract a `country` feature as well as change the country names that no longer exist.
#
# Wrangle the Country Names
#
# You'll need to use a 3 letter country code for each country. You might have to change some country names.
#
# * Russia is the Russian Federation
# * New Mexico should be USA
# * Yellow Sea refers to China
# * Shahrud Missile Test Site should be Iran
# * Pacific Missile Range Facility should be USA
# * Barents Sea should be Russian Federation
# * Gran Canaria should be USA
#
#
# You can use the iso3166 package to convert the country names to Alpha3 format.

# %%
# df_data.head()
# print(type(df_data))
overrides = {
    'Russia': 'Russian Federation',
    'New Mexico': 'USA',
    'Yellow Sea': 'China',
    'Shahrud Missile Test Site': 'Iran',
    'Pacific Missile Range Facility': 'USA',
    'Barents Sea': 'Russian Federation',
    'Gran Canaria': 'USA'
}
for row in df_data.index:
  location = df_data['Location'][row]
  locationlist = location.split(', ')
  try:
    result = countries.get(locationlist[len(locationlist) -1 ])
  except KeyError:
    result = overrides[locationlist[len(locationlist) -1 ]]
    result = countries.get(result)
  # print(result.alpha3)
  # print(df_data.loc[row])
  df_data.loc[row, ['ISO']] = result.alpha3
  # print(df_data.loc[row])
df_countries = df_data.groupby(['ISO'],as_index=False)
#

# %%
launches_by_country=[]
for i in df_data.ISO.unique():
    launches_by_country.append(df_data['ISO'].value_counts()[i])
world_map = px.choropleth(
                          locations=df_data.ISO.unique(),
                          color=launches_by_country,
                          color_continuous_scale=px.colors.sequential.matter,
                          hover_name=df_data.ISO.unique()
                          )
world_map.update_layout(coloraxis_showscale=True)
world_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="80e0dc4d-0ee0-49a7-8ee0-418049972601" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80e0dc4d-0ee0-49a7-8ee0-418049972601")) {                    Plotly.newPlot(                        "80e0dc4d-0ee0-49a7-8ee0-418049972601",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocations=%{location}\u003cbr\u003ecolor=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["USA","CHN","KAZ","JPN","NZL","RUS","FRA","IND"],"locations":["USA","CHN","KAZ","JPN","NZL","RUS","FRA","IND"],"name":"","z":[490,159,46,40,13,54,95,67],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar": ...

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Failures by Country

# %%
data_failures=df_data[df_data.Mission_Status!='Success']
fail_by_country=[]
for i in data_failures.ISO.unique():
    fail_by_country.append(data_failures['ISO'].value_counts()[i])

# %%
world_map = px.choropleth(
                          locations=data_failures.ISO.unique(),
                          color=fail_by_country,
                          color_continuous_scale=px.colors.sequential.matter,
                          hover_name=data_failures.ISO.unique()
                          )
world_map.update_layout(coloraxis_showscale=True)
world_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="63e301e8-c9cb-4a55-9ae8-77af082a9382" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63e301e8-c9cb-4a55-9ae8-77af082a9382")) {                    Plotly.newPlot(                        "63e301e8-c9cb-4a55-9ae8-77af082a9382",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocations=%{location}\u003cbr\u003ecolor=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["CHN","NZL","USA","FRA","IND","KAZ","RUS"],"locations":["CHN","NZL","USA","FRA","IND","KAZ","RUS"],"name":"","z":[7,2,28,3,8,3,3],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# # Create a Plotly Sunburst Chart of the countries, organisations, and mission status.

# %%
burst = px.sunburst(
    df_data,
    path=[
        'ISO',
        'Organisation',
        'Mission_Status'
    ],
)
burst.update_layout(
                    coloraxis_showscale=False
                    )
burst.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="82fd5b4a-eabd-4750-99db-474ff7bec810" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82fd5b4a-eabd-4750-99db-474ff7bec810")) {                    Plotly.newPlot(                        "82fd5b4a-eabd-4750-99db-474ff7bec810",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["FRA\u002fArianespace\u002fFailure","CHN\u002fCASC\u002fFailure","USA\u002fEER\u002fFailure","RUS\u002fEurockot\u002fFailure","CHN\u002fExPace\u002fFailure","IND\u002fISRO\u002fFailure","KAZ\u002fKosmotras\u002fFailure","USA\u002fMartin Marietta\u002fFailure","USA\u002fNASA\u002fFailure","USA\u002fNorthrop\u002fFailure","NZL\u002fRocket Lab\u002fFailure","USA\u002fSandia\u002fFailure","USA\u002fSpaceX\u002fFailure","USA\u002fUS Air Force\u002fFailure","KAZ\u002fVKS RF\u002fFailure","USA\u002fVirgin Orbit\u002fFailure","FRA\u002fArianespace\u002fPartial Failure","USA\u002fBoeing\u002fPartial Failure","CHN\u002fCASC\u002fPartial Failure","IND\u002fISRO\u002fPartial Failure","USA\u002fNASA\u002fPartial Failure","USA\u002fNorthrop\u002fPartial Failure","KAZ\u002fRoscosmos\u002fPartial Failure","USA\u002fSpaceX\u002fPartial Failure","USA\u002fULA\u002fPartial Failure","USA\u002fUS Air Force\u002fPartial Failure","RUS\u002fVKS RF\u002fPartial Failure","USA\u002fSpaceX\u002fPrelaunch Failure","FRA\u002fArianespace\u002fSuccess","KAZ\u002fArianespace\u002fSuccess","USA\u002fBoeing\u002fSuccess","CHN\u002fCASC\u002fSuccess","FRA\u002fESA\u002fSuccess","RUS\u002fEurockot\u002fSuccess","KAZ\u002fILS\u002fSuccess","USA\u002fILS\u002fSuccess","IND\u002fISRO\u002fSuccess","JPN\u002fJAXA\u002fSuccess","KAZ\u002fKosmotras\u002fSuccess","RUS\u002fKosmotras\u002fSuccess","USA\u002fLockheed\u002fSuccess","JPN\u002fMHI\u002fSuccess","USA\u002fMartin Marietta\u002fSuccess","USA\u002fNASA\u002fSuccess","USA\u002fNorthrop\u002fSuccess","KAZ\u002fRVSN USSR\u002fSuccess","NZL\u002fRocket Lab\u002fSuccess","KAZ\u002fRoscosmos\u002fSuccess","RUS\u002fRoscosmos\u002fSuccess","USA\u002fSpaceX\u002fSuccess","USA\u002fULA\u002fSuccess","USA\u002fUS Air Force\u002fSuccess","KAZ\u002fVKS RF\u002fSuccess","RUS\u002fVKS RF\u002fSuccess","FRA\u002fArianespace","KAZ\u002fArianespace","USA\u002fBoeing","CHN\u002fCASC","USA\u002fEER","FRA\u002fESA","RUS\u002fEurockot","CHN\u002fExPace","KAZ\u002fILS","USA\u002fILS","IND\u002fISRO","JPN\u002fJAXA","KAZ\u002fKosmotras","RUS\u002fKosmotras","USA\u002fLockheed","JPN\u002fMHI","USA\u002fMartin Marietta","USA\u002fNASA","USA\u002fNorthrop","KAZ\u002fRVSN USSR","NZL\u002fRocket Lab","KAZ\u002fRoscosmos","RUS\u002fRoscosmos","USA\u002fSandia","USA\u002fSpaceX","USA\u002fULA","USA\u002fUS Air Force","KAZ\u002fVKS RF","RUS\u002fVKS RF","USA\u002fVirgin Orbit","CHN","FRA","IND","JPN","KAZ","NZL","RUS","USA"],"labels":["Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Failure","Partial Failure","Partial Failure","Partial Failure","Partial Failure","Partial Failure","Partial Failure","Partial Failure","Partial Failure","Partial Failure","Partial Failure","Partial Failure","Prelaunch Failure","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Success","Arianespace","Arianespace","Boeing","CASC","EER","ESA","Eurockot","ExPace","ILS","ILS","ISRO","JAXA","Kosmotra ...

# %% [markdown]
# # Analyse the Total Amount of Money Spent by Organisation on Space Missions

# %%
print(df_data.groupby(by='Organisation')['Price'])
# Out:
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x7e4d10594ca0>

# %%
for row in df_data.index:
  price = df_data.loc[row, ['Price']]
  try:
    intprice = float(price)
  except ValueError:
    intprice = float(price.str.replace(",",""))
  df_data.loc[row, ['Price']] = intprice

# %%
df_data.groupby(by='Organisation')['Price'].sum()
# Out:
# Organisation
# Arianespace       16,345.00
# Boeing             1,241.00
# CASC               6,340.26
# EER                   20.00
# ESA                   37.00
# Eurockot             543.40
# ExPace                28.30
# ILS                1,320.00
# ISRO               2,177.00
# JAXA                 168.00
# Kosmotras            638.00
# Lockheed             280.00
# MHI                3,532.50
# Martin Marietta      721.40
# NASA              76,280.00
# Northrop           3,930.00
# RVSN USSR         10,000.00
# Rocket Lab            97.50
# Roscosmos          1,187.50
# Sandia                15.00
# SpaceX             5,444.00
# ULA               14,798.00
# US Air Force       1,550.92
# VKS RF             1,548.90
# Virgin Orbit          12.00
# Name: Price, dtype: object

# %% [markdown]
# # Analyse the Amount of Money Spent by Organisation per Launch

# %%
df_data.groupby(by='Organisation')['Price'].mean()
# Out:
# Organisation
# Arianespace         170.26
# Boeing              177.29
# CASC                 40.13
# EER                  20.00
# ESA                  37.00
# Eurockot             41.80
# ExPace               28.30
# ILS                 101.54
# ISRO                 32.49
# JAXA                 56.00
# Kosmotras            29.00
# Lockheed             35.00
# MHI                  95.47
# Martin Marietta      80.16
# NASA                511.95
# Northrop             47.35
# RVSN USSR         5,000.00
# Rocket Lab            7.50
# Roscosmos            51.63
# Sandia               15.00
# SpaceX               54.99
# ULA                 151.00
# US Air Force         59.65
# VKS RF               46.94
# Virgin Orbit         12.00
# Name: Price, dtype: float64

# %% [markdown]
# # Chart the Number of Launches per Year

# %%
for row in df_data.index:
  date = df_data['Date'][row]
  datelist = date.split(' ')
  df_data.loc[row, ['year']] = datelist[3]
  df_data.loc[row, ['month']] = datelist[1]
  # print(df_data.loc[row])
count_by_year = []
for i in df_data.year.unique():
  count_by_year.append(df_data['year'].value_counts()[i])
print(count_by_year)
# Out:
# [52, 73, 88, 66, 64, 39, 41, 33, 25, 29, 29, 31, 28, 29, 27, 15, 17, 20, 17, 10, 16, 14, 18, 18, 14, 10, 16, 12, 12, 7, 11, 6, 5, 3, 3, 10, 6, 5, 4, 2, 1, 2, 2, 1, 8, 10, 8, 3, 2, 2]

# %%
fig = px.area(df_data, x=df_data.year.unique(), y=count_by_year)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="143f7c45-8b91-4228-ad1c-e2fabb569ca8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("143f7c45-8b91-4228-ad1c-e2fabb569ca8")) {                    Plotly.newPlot(                        "143f7c45-8b91-4228-ad1c-e2fabb569ca8",                        [{"fillpattern":{"shape":""},"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":["2020","2019","2018","2017","2016","2015","2014","2013","2012","2011","2010","2009","2008","2007","2006","2005","2004","2003","2002","2001","2000","1999","1998","1997","1996","1995","1994","1993","1992","1991","1990","1989","1988","1987","1986","1985","1984","1983","1982","1981","1973","1972","1971","1970","1969","1968","1967","1966","1965","1964"],"xaxis":"x","y":[52,73,88,66,64,39,41,33,25,29,29,31,28,29,27,15,17,20,17,10,16,14,18,18,14,10,16,12,12,7,11,6,5,3,3,10,6,5,4,2,1,2,2,1,8,10,8,3,2,2],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoo ...

# %% [markdown]
# # Chart the Number of Launches Month-on-Month until the Present
#
# Which month has seen the highest number of launches in all time? Superimpose a rolling average on the month on month time series chart.

# %%
count_by_month = []
for i in df_data.month.unique():
  count_by_month.append(df_data['month'].value_counts()[i])

# %%
fig = px.area(df_data, x=df_data.month.unique(), y=count_by_month)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="8ac85330-e7c0-489a-80ef-1ed5b6592045" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ac85330-e7c0-489a-80ef-1ed5b6592045")) {                    Plotly.newPlot(                        "8ac85330-e7c0-489a-80ef-1ed5b6592045",                        [{"fillpattern":{"shape":""},"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":["Aug","Jul","Jun","May","Apr","Mar","Feb","Jan","Dec","Nov","Oct","Sep"],"xaxis":"x","y":[82,77,85,86,91,77,60,66,92,77,83,88],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatte ...

# %% [markdown]
# # Launches per Month: Which months are most popular and least popular for launches?
#
# Some months have better weather than others. Which time of year seems to be best for space missions?

# %%
print(df_data['month'].value_counts())
data = df_data['month'].value_counts().max()
print(type(data))
# Out:
# Dec    92
# Apr    91
# Sep    88
# May    86
# Jun    85
# Oct    83
# Aug    82
# Jul    77
# Mar    77
# Nov    77
# Jan    66
# Feb    60
# Name: month, dtype: int64
# <class 'numpy.int64'>

# %%
df_data['month'].value_counts().min()
# Out:
# 60

# %% [markdown]
# # How has the Launch Price varied Over Time?
#
# Create a line chart that shows the average price of rocket launches over time.

# %%
mean_price = df_data.groupby(by='year')['Price'].mean()

# %%
plt.figure(figsize=(15,17))
plt.xticks(rotation=90)
plt.plot(mean_price)

# %% [markdown]
# [link text](https://)# Chart the Number of Launches over Time by the Top 10 Organisations.
#
# How has the dominance of launches changed over time between the different players?

# %%
test = df_data.groupby(['year','Organisation' ]).size().to_frame('size').reset_index()
line = px.line(
    test,
    x='year',
    y='size',
    color='Organisation'
)
line.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="9ad60458-a7b4-4960-a988-d6b976aced14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ad60458-a7b4-4960-a988-d6b976aced14")) {                    Plotly.newPlot(                        "9ad60458-a7b4-4960-a988-d6b976aced14",                        [{"hovertemplate":"Organisation=US Air Force\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US Air Force","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"US Air Force","orientation":"v","showlegend":true,"x":["1964","1965","1966","1967","1968","1969"],"xaxis":"x","y":[2,2,3,7,8,4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=NASA\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NASA","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"NASA","orientation":"v","showlegend":true,"x":["1967","1968","1969","1970","1971","1972","1973","1981","1982","1983","1984","1985","1986","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2005","2006","2007","2008","2009","2010","2011"],"xaxis":"x","y":[1,2,4,1,2,2,1,2,3,4,5,9,2,2,5,6,6,8,7,7,7,7,8,5,3,5,6,5,1,1,3,3,4,6,3,3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=CASC\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CASC","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"CASC","orientation":"v","showlegend":true,"x":["1982","1983","1984","1985","1986","1987","1988","1990","1992","1993","1994","1996","1997","1998","1999","2000","2002","2003","2004","2005","2006","2007","2008","2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[1,1,1,1,1,2,1,1,2,1,3,1,3,4,3,3,2,5,8,3,5,8,6,1,15,12,27,21,16],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=RVSN USSR\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RVSN USSR","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RVSN USSR","orientation":"v","showlegend":true,"x":["1987","1988"],"xaxis":"x","y":[1,1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=Martin Marietta\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Martin Marietta","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Martin Marietta","orientation":"v","showlegend":true,"x":["1988","1989","1990","1992","1993","1994"],"xaxis":"x","y":[1,1,3,2,1,1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=Northrop\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Northrop","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Northrop","orientation":"v","showlegend":true,"x":["1990","1991","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2016","2017","2018","2019","2020"],"xaxis":"x","y":[1,1,2,4,2,5,5,8,4,5,1,1,4,1,3,3,2,2,2,2,4,1,5,3,2,3,2,3,2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=ISRO\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISRO","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ISRO","orientation":"v","showlegend":true,"x":["1993","1994","1996","1997","1999","2001","2002","2003","2004","2005","2006","2007","2 ...

# %% [markdown]
# # Cold War Space Race: USA vs USSR
#
# The cold war lasted from the start of the dataset up until 1991.

# %% [markdown]
# ## Create a Plotly Pie Chart comparing the total number of launches of the USSR and the USA
#
# Hint: Remember to include former Soviet Republics like Kazakhstan when analysing the total number of launches.

# %% [markdown]
# ## Create a Chart that Shows the Total Number of Launches Year-On-Year by the Two Superpowers

# %% [markdown]
# ## Chart the Total Number of Mission Failures Year on Year.

# %% [markdown]
# ## Chart the Percentage of Failures over Time
#
# Did failures go up or down over time? Did the countries get better at minimising risk and improving their chances of success over time?

# %% [markdown]
# # For Every Year Show which Country was in the Lead in terms of Total Number of Launches up to and including including 2020)
#
# Do the results change if we only look at the number of successful launches?

# %% [markdown]
# # Create a Year-on-Year Chart Showing the Organisation Doing the Most Number of Launches
#
# Which organisation was dominant in the 1970s and 1980s? Which organisation was dominant in 2018, 2019 and 2020?

# %%
test = df_data.groupby(['year','Organisation' ]).size().to_frame('size').reset_index()
line = px.line(
    test,
    x='year',
    y='size',
    color='Organisation'
)
line.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="73f7c67f-f052-4322-9a39-91ecefe0a2f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73f7c67f-f052-4322-9a39-91ecefe0a2f8")) {                    Plotly.newPlot(                        "73f7c67f-f052-4322-9a39-91ecefe0a2f8",                        [{"hovertemplate":"Organisation=US Air Force\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US Air Force","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"US Air Force","orientation":"v","showlegend":true,"x":["1964","1965","1966","1967","1968","1969"],"xaxis":"x","y":[2,2,3,7,8,4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=NASA\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NASA","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"NASA","orientation":"v","showlegend":true,"x":["1967","1968","1969","1970","1971","1972","1973","1981","1982","1983","1984","1985","1986","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2005","2006","2007","2008","2009","2010","2011"],"xaxis":"x","y":[1,2,4,1,2,2,1,2,3,4,5,9,2,2,5,6,6,8,7,7,7,7,8,5,3,5,6,5,1,1,3,3,4,6,3,3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=CASC\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CASC","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"CASC","orientation":"v","showlegend":true,"x":["1982","1983","1984","1985","1986","1987","1988","1990","1992","1993","1994","1996","1997","1998","1999","2000","2002","2003","2004","2005","2006","2007","2008","2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[1,1,1,1,1,2,1,1,2,1,3,1,3,4,3,3,2,5,8,3,5,8,6,1,15,12,27,21,16],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=RVSN USSR\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RVSN USSR","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RVSN USSR","orientation":"v","showlegend":true,"x":["1987","1988"],"xaxis":"x","y":[1,1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=Martin Marietta\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Martin Marietta","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Martin Marietta","orientation":"v","showlegend":true,"x":["1988","1989","1990","1992","1993","1994"],"xaxis":"x","y":[1,1,3,2,1,1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=Northrop\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Northrop","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Northrop","orientation":"v","showlegend":true,"x":["1990","1991","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2016","2017","2018","2019","2020"],"xaxis":"x","y":[1,1,2,4,2,5,5,8,4,5,1,1,4,1,3,3,2,2,2,2,4,1,5,3,2,3,2,3,2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Organisation=ISRO\u003cbr\u003eyear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISRO","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ISRO","orientation":"v","showlegend":true,"x":["1993","1994","1996","1997","1999","2001","2002","2003","2004","2005","2006","2007","2 ...
